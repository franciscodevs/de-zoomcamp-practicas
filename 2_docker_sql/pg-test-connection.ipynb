# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
query = """
SELECT * FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND
    schemaname != 'information_schema';


"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public     zones       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
query = """
SELECT * FROM yellow_taxi_data LIMIT 100


"""

pd.read_sql(query, con=engine)
# Out:
#     index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0     688         2  2021-01-01 00:55:06   2021-01-01 00:58:30
# 1     689         2  2021-01-01 01:00:55   2021-01-01 01:13:24
# 2     690         2  2021-01-01 00:24:18   2021-01-01 00:27:07
# 3     691         2  2021-01-01 00:32:07   2021-01-01 00:33:46
# 4     692         2  2021-01-01 00:52:29   2021-01-01 00:55:42
# ..    ...       ...                  ...                   ...
# 95    783         2  2021-01-01 00:37:48   2021-01-01 00:39:56
# 96    784         2  2021-01-01 00:07:45   2021-01-01 00:23:39
# 97    785         2  2021-01-01 00:31:59   2021-01-01 00:41:36
# 98    786         2  2021-01-01 00:22:09   2021-01-01 00:41:35
# 99    787         2  2021-01-01 00:42:30   2021-01-01 00:44:16
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               2.0           1.01         1.0                  N
# 1               2.0           3.79         1.0                  N
# 2               2.0           0.65         1.0                  N
# 3               2.0           0.38         1.0                  N
# 4               2.0           0.55         1.0                  N
# ..              ...            ...         ...                ...
# 95              1.0           0.53         1.0                  N
# 96              1.0           2.36         1.0                  N
# 97              1.0           1.73         1.0                  N
# 98              1.0           4.82         1.0                  N
# 99              1.0           0.46         1.0                  N
#
#     PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0            236           141             1          5.0    0.5      0.5
# 1            140             7             1         13.0    0.5      0.5
# 2             68            68             2          4.0    0.5      0.5
# 3             68            68             2          3.5    0.5      0.5
# 4            246            48             2          4.5    0.5      0.5
# ..           ...           ...           ...          ...    ...      ...
# 95           141           263             2          4.0    0.5      0.5
# 96           230           238             1         12.5    0.5      0.5
# 97           142            68             1          8.5    0.5      0.5
# 98           186            75             2         17.0    0.5      0.5
# 99            75            74             1          3.5    0.5      0.5
#
#     tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0         2.20           0.0                    0.3         11.00
# 1         5.04           0.0                    0.3         21.84
# 2         0.00           0.0                    0.3          7.80
# 3         0.00           0.0                    0.3          7.30
# 4         0.00           0.0                    0.3          8.30
# ..         ...           ...                    ...           ...
# 95        0.00           0.0                    0.3          7.80
# 96        1.70           0.0                    0.3         18.00
# 97        4.30           0.0                    0.3         16.60
# 98        0.00           0.0                    0.3         20.80
# 99        0.00           0.0                    0.3          4.80
#
#     congestion_surcharge airport_fee
# 0                    2.5        None
# 1                    2.5        None
# 2                    2.5        None
# 3                    2.5        None
# 4                    2.5        None
# ..                   ...         ...
# 95                   2.5        None
# 96                   2.5        None
# 97                   2.5        None
# 98                   2.5        None
# 99                   0.0        None
#
# [100 rows x 20 columns]
